# %%
from rdkit.Chem import AllChem
from chemistry_methods.drawing import draw_molecule
from chemistry_methods.reaction_analysis import extract_info_from_molecule
from data_methods.dataset_construction import extract_relevant_information

# %%
mol = AllChem.MolFromSmiles("CC(C)(C)OC(=O)N1CCN(c2cc(-c3cc(Cl)ccc3OCc3ccccc3)ccn2)CC1")
AllChem.SanitizeMol(mol)

rp, nrp = extract_info_from_molecule(mol, [0, 1])
print(rp)

display(draw_molecule(mol))
display(draw_molecule(rp[2][0]))
display(draw_molecule(nrp[2][0]))
# Out:
# (['*C(*)(*)C'], ['[#0]-[#6](-[#0])(-[#0])-[#6]'], [<rdkit.Chem.rdchem.Mol object at 0x000002158FDA8BC0>], [<rdkit.Chem.rdchem.Mol object at 0x000002158FDA89E0>])
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x2158FDE48D0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x2158F940A20>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x200 at 0x2158FCFAB38>
